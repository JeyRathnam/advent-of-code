# %%
def getNeighbouringOccupancy(x, y, lines, debug=False):
    occupancy = 0
    
    #left
    ty = y
    while ty-1 >= 0:
        if lines[x][ty-1] == '#':
            occupancy += 1
            if debug:
                print('Left', (x, ty-1))
            break
        elif lines[x][ty-1] == 'L':
            break
            
        ty -= 1
        
    #top
    tx = x
    while tx-1 >= 0:
        if lines[tx-1][y] == '#':
            occupancy += 1
            if debug:
                print('top', (tx-1, y))
            break
        elif lines[tx-1][y] == 'L':
            break
        tx -= 1
        
    #right
    ty = y
    while ty+1 <= len(lines[0])-1:
        if lines[x][ty+1] == '#':
            occupancy += 1
            if debug:
                print('right', (x, ty+1))
            break
        elif lines[x][ty+1] == 'L':
            break
        ty += 1
        
    #bottom
    tx = x
    while tx+1 <= len(lines)-1:
        if lines[tx+1][y] == '#':
            occupancy += 1
            if debug:
                print('bottom', (tx+1, y))
            break
        elif lines[tx+1][y] == 'L':
            break
        tx += 1
        
        
        
    #top left
    tx = x
    ty = y
    while tx-1 >= 0 and ty-1 >= 0:
        if lines[tx-1][ty-1] == '#':
            occupancy += 1
            if debug:
                print('top left', (tx-1, ty-1))
            break
        elif lines[tx-1][ty-1] == 'L':
            break
        tx -= 1
        ty -= 1
        
        
    #top right 
    tx = x
    ty = y
    while tx-1 >=0 and ty+1 <=len(lines[0])-1:
        if lines[tx-1][ty+1] == '#':
            occupancy += 1 
            if debug:
                print('top right', (tx-1, ty+1))
            break
        elif lines[tx-1][ty+1] == 'L':
            break
        tx -= 1
        ty += 1
        
    #bottom left
    tx = x
    ty = y
    while tx+1 <= len(lines)-1 and ty-1 >= 0:
        if lines[tx+1][ty-1] == '#':
            occupancy += 1
            if debug:
                print('bottom left', (tx+1, ty-1))
            break
        elif lines[tx+1][ty-1] == 'L':
            break
        tx += 1
        ty -= 1
        
    #bottom right
    tx = x
    ty = y
    while tx+1 <= len(lines)-1 and ty+1 <= len(lines[0])-1:
        if lines[tx+1][ty+1] == '#':
            occupancy += 1
            if debug:
                print('bottom right', (tx+1, ty+1))
            break
        elif lines[tx+1][ty+1] == 'L':
            break
        tx += 1
        ty += 1
        
    return occupancy

def printSeats(seats):
    for x in range(len(seats[0])):
        for y in range(len(seats)):
            print(seats[x][y], end="")
        print()
def compareTwoLists(l1, l2):
    if len(l1) != len(l2):
        return False
    
    for x in range(len(l1)):
        for y in range(len(l1[x])):
            if l1[x][y] != l2[x][y]:
                return False
    return True

def countSeats(seats):
    count = 0
    for x in range(len(seats)):
        for y in range(len(seats[0])):
            if seats[x][y] == '#':
                count += 1
    return count



def topRight(x, y, lines, debug=False):
    tx = x
    ty = y
    occupancy = 0
    while tx-1 >=0 and ty+1 <=len(lines[0])-1:
        if lines[tx-1][ty+1] == '#':
            occupancy += 1 
            if debug:
                print('top right', (tx-1, ty+1))
            break
        elif lines[tx-1][ty+1] == 'L':
            break
        tx -= 1
        ty += 1
    return occupancy

# %%
import os

def seatingSeat(lines):
    output = []
    row = ['.'] * len(lines[0])
    for x in range(len(lines)):
            output.append(row[:])
    for x in range(len(lines)):
        for y in range(len(lines[0])):
            if lines[x][y] == 'L':
                if getNeighbouringOccupancy(x, y, lines) == 0:
                    output[x][y] = '#'
                else:
                    output[x][y] = 'L'

            elif lines[x][y] == '#':
                if getNeighbouringOccupancy(x, y, lines) >= 5:
                    output[x][y] = 'L'
                else:
                    output[x][y] = '#'
    if compareTwoLists(output, lines):
#         printSeats(output)
        print(countSeats(output))
    else:
        seatingSeat(output)
        
filename = 'input.txt'
with open(os.path.join(os.path.abspath(''), filename), 'r') as f:
        lines = f.read().splitlines()
        seatingSeat(lines)
#         print(getNeighbouringOccupancy(8, 0, lines, True))
# Out:
# #L#L#.L#L#L#L#L#L#L#L#L#L#L#L#L#.L#L#L#L.#L#L#L#L#L.#L#L#L#L#L#.L#L#L#L#L#L#L#.L#L#.L#L#.L#L#L#
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-e73c9f01741f> in <module>
#      28 with open(os.path.join(os.path.abspath(''), filename), 'r') as f:
#      29         lines = f.read().splitlines()
# ---> 30         seatingSeat(lines)
#      31 #         print(getNeighbouringOccupancy(8, 0, lines, True))
#
# <ipython-input-36-e73c9f01741f> in seatingSeat(lines)
#      23         print(countSeats(output))
#      24     else:
# ---> 25         seatingSeat(output)
#      26
#      27 filename = 'input.txt'
#
# <ipython-input-36-e73c9f01741f> in seatingSeat(lines)
#      23         print(countSeats(output))
#      24     else:
# ---> 25         seatingSeat(output)
#      26
#      27 filename = 'input.txt'
#
# <ipython-input-36-e73c9f01741f> in seatingSeat(lines)
# ...
